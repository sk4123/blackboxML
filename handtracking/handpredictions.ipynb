# %%
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

home_dir = "C:/Users/Alex/Desktop/blackboxML"
train_loc = "train1"
run = "test"

image_loc = home_dir + "images/see_cam/full/" + run
model_loc = "datasets/" + train_loc + "/weights/best.pt"
model = YOLO(model_loc)

im0 = cv2.imread(image_loc + "")

# Create an annotator object to draw on the frame
annotator = Annotator(im0, line_width=2)

# Perform object tracking on the current frame
results = model.track(im0, persist=True)

# Check if tracking IDs and masks are present in the results
if results[0].boxes.id is not None and results[0].masks is not None:
    # Extract masks and tracking IDs
    masks = results[0].masks.xy
    track_ids = results[0].boxes.id.int().cpu().tolist()

    # Annotate each mask with its corresponding tracking ID and color
    for mask, track_id in zip(masks, track_ids):
        annotator.seg_bbox(mask=mask, mask_color=colors(track_id, True), track_label=str(track_id))

# Display the annotated frame
cv2.imshow("instance-segmentation-object-tracking", im0)

# Make a function which saves annotated images to a video file - https://github.com/ChristineDewi/ultralytics-YOLOv8-Hand-Detection/blob/main/examples/object_tracking.ipynb

# %%
from collections import defaultdict
import cv2
import csv
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# Dictionary to store tracking history with default empty lists
track_history = defaultdict(lambda: [])

# Load the YOLO model with segmentation capabilities
home_dir = "C:/Users/Alex/Desktop/blackboxML/"
train_loc = "train1"
run = "test"

image_loc = f"{home_dir}images/see_cam/full/"
model_loc = f"datasets/{train_loc}/weights/best.pt"
model = YOLO(model_loc)

# Open the video file
cap = cv2.VideoCapture(f"{image_loc}IMG_6103.mov")

# Retrieve video properties: width, height, and frames per second
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Initialize video writer to save the output video with the specified properties
out = cv2.VideoWriter("wtf.avi", cv2.VideoWriter_fourcc(*"MJPG"), fps, (w, h))

# Open the CSV file to write the coordinates
csv_file = open("coordinates.csv", mode="w", newline="")
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["Frame", "Tracking ID", "X Coordinate", "Y Coordinate"])  # Writing the header row

while True:
    # Read a frame from the video
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    # Create an annotator object to draw on the frame
    annotator = Annotator(im0, line_width=2)

    # Perform object tracking on the current frame
    results = model.track(im0, persist=True)

    # Check if tracking IDs and masks are present in the results
    if results[0].boxes.id is not None and results[0].masks is not None:
        # Extract masks and tracking IDs
        masks = results[0].masks.xy
        track_ids = results[0].boxes.id.int().cpu().tolist()

        # Debugging: Print track IDs and masks to check if they are being processed
        print(f"Track IDs: {track_ids}")
        print(f"Masks: {masks}")

        # Annotate each mask with its corresponding tracking ID and color
        for mask, track_id in zip(masks, track_ids):
            annotator.seg_bbox(mask=mask, mask_color=colors(track_id, True), track_label=str(track_id))

            # Calculate the bounding box (min and max x and y values) from the mask
            mask_points = mask.reshape((-1, 2))  # Flatten mask to a list of points
            x_min, y_min = mask_points.min(axis=0)
            x_max, y_max = mask_points.max(axis=0)

            # Draw a bounding box on the image
            cv2.rectangle(im0, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (255, 0, 0), 2)

            # Calculate the centroid of the mask (to represent the hand's center)
            centroid = mask_points.mean(axis=0)  # Calculate the center of the mask
            centroid = tuple(centroid.astype(int))

            # Debugging: Print centroid coordinates to ensure they are calculated correctly
            print(f"Centroid for Track ID {track_id}: {centroid}")

            # Display the centroid coordinates on the frame
            cv2.putText(im0, f"ID: {track_id} ({centroid[0]}, {centroid[1]})", 
                        (centroid[0] + 10, centroid[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.5, (255, 0, 0), 2)

            # Optionally, you can draw a circle at the centroid position
            cv2.circle(im0, centroid, 5, (0, 0, 255), -1)

            # Save the coordinates to the CSV file
            csv_writer.writerow([int(cap.get(cv2.CAP_PROP_POS_FRAMES)), track_id, centroid[0], centroid[1]])

    # Write the annotated frame to the output video
    out.write(im0)
    # Display the annotated frame
    cv2.imshow("instance-segmentation-object-tracking", im0)

    # Exit the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release the video writer and capture objects, and close all OpenCV windows
out.release()
cap.release()
csv_file.close()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 hand, 26.1ms
# Speed: 4.1ms preprocess, 26.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 78.4ms
# Speed: 5.2ms preprocess, 78.4ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 66.5ms
# Speed: 1.0ms preprocess, 66.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.7ms
# Speed: 3.0ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 1.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.3ms
# Speed: 3.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 4.1ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 1.1ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.1ms
# Speed: 3.1ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 4.1ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.0ms
# Speed: 5.1ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.2ms
# Speed: 3.0ms preprocess, 7.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.0ms
# Speed: 5.1ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 0.9ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 5.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.6ms
# Speed: 1.9ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.1ms
# Speed: 4.0ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.1ms
# Speed: 5.1ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.1ms
# Speed: 3.1ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.0ms
# Speed: 3.1ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.5ms
# Speed: 4.0ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.6ms
# Speed: 3.0ms preprocess, 19.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.2ms
# Speed: 3.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 20.1ms
# Speed: 1.1ms preprocess, 20.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.5ms
# Speed: 2.9ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.6ms
# Speed: 2.0ms preprocess, 19.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 21.2ms
# Speed: 4.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.1ms
# Speed: 3.0ms preprocess, 15.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 20.2ms
# Speed: 4.0ms preprocess, 20.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.7ms
# Speed: 4.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.5ms
# Speed: 3.1ms preprocess, 18.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.6ms
# Speed: 4.0ms preprocess, 18.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.7ms
# Speed: 4.0ms preprocess, 17.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.2ms
# Speed: 5.5ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.1ms
# Speed: 1.5ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.7ms
# Speed: 4.0ms preprocess, 19.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.5ms
# Speed: 3.1ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 20.1ms
# Speed: 2.5ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
from collections import defaultdict
import cv2
import csv
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# Dictionary to store tracking history with default empty lists
track_history = defaultdict(lambda: [])

# Load the YOLO model with segmentation capabilities
home_dir = "C:/Users/Alex/Desktop/blackboxML/"
train_loc = "train1"
run = "test"

image_loc = f"{home_dir}images/see_cam/full/"
model_loc = f"datasets/{train_loc}/weights/best.pt"
model = YOLO(model_loc)

# Open the video file
cap = cv2.VideoCapture(f"{image_loc}shortenedflightnov.mp4")

# Retrieve video properties: width, height, and frames per second
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Initialize video writer to save the output video with the specified properties
out = cv2.VideoWriter("wtf.avi", cv2.VideoWriter_fourcc(*"MJPG"), fps, (w, h))

# Open the CSV file to write the coordinates
csv_file = open("coordinates.csv", mode="w", newline="")
csv_writer = csv.writer(csv_file)
csv_writer.writerow(["Frame", "Tracking ID", "X Coordinate", "Y Coordinate"])  # Writing the header row

while True:
    # Read a frame from the video
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    # Create an annotator object to draw on the frame
    annotator = Annotator(im0, line_width=2)

    # Perform object tracking on the current frame
    results = model.track(im0, persist=True)

    # Debugging: Print the results object to see available attributes
    print(f"Results: {results}")

    # Check if bounding boxes are present and if tracking IDs are available
    if results[0].boxes is not None and results[0].boxes.id is not None:
        # Extract bounding boxes and track IDs
        boxes = results[0].boxes.xyxy  # Format: [x_min, y_min, x_max, y_max]
        track_ids = results[0].boxes.id.int().cpu().tolist()

        # Debugging: Print bounding boxes and track IDs to check if they are being processed
        print(f"Track IDs: {track_ids}")
        print(f"Boxes: {boxes}")

        # Annotate each bounding box with its corresponding tracking ID and color
        for box, track_id in zip(boxes, track_ids):
            x_min, y_min, x_max, y_max = box  # Extract coordinates from the bounding box

            # Draw a bounding box on the image
            cv2.rectangle(im0, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (255, 0, 0), 2)

            # Calculate the centroid of the bounding box (center of the hand)
            centroid = ((x_min + x_max) // 2, (y_min + y_max) // 2)

            # Debugging: Print centroid coordinates to ensure they are calculated correctly
            print(f"Centroid for Track ID {track_id}: {centroid}")

            # Display the centroid coordinates on the frame
            cv2.putText(im0, f"ID: {track_id} ({int(centroid[0])}, {int(centroid[1])})", 
                        (int(centroid[0]) + 10, int(centroid[1]) - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            # Optionally, you can draw a circle at the centroid position
            cv2.circle(im0, (int(centroid[0]), int(centroid[1])), 5, (0, 0, 255), -1)

            # Save the coordinates to the CSV file
            csv_writer.writerow([int(cap.get(cv2.CAP_PROP_POS_FRAMES)), track_id, int(centroid[0]), int(centroid[1])])

    else:
        print("No objects or tracking IDs detected in this frame.")

    # Write the annotated frame to the output video
    out.write(im0)
    # Display the annotated frame
    cv2.imshow("instance-segmentation-object-tracking", im0)

    # Exit the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release the video writer and capture objects, and close all OpenCV windows
out.release()
cap.release()
csv_file.close()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 hand, 26.0ms
# Speed: 6.7ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[120,  98,  61],
#         [144, 122,  85],
#         [187, 144, 101],
#         ...,
#         [ 93,  91,  87],
#         [ 93,  91,  87],
#         [ 93,  91,  87]],
#
#        [[104,  82,  45],
#         [132, 110,  73],
#         [185, 142,  99],
#         ...,
#         [ 93,  91,  87],
#         [ 93,  91,  87],
#         [ 93,  91,  87]],
#
#        [[ 90,  68,  31],
#         [118,  96,  59],
#         [171, 128,  85],
#         ...,
#         [ 93,  91,  87],
#         [ 93,  91,  87],
#         [ 93,  91,  87]],
#
#        ...,
#
#        [[188, 103,  44],
#         [188, 103,  44],
#         [188, 103,  44],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[188, 103,  44],
#         [188, 103,  44],
#         [188, 103,  44],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[188, 103,  44],
#         [188, 103,  44],
#         [188, 103,  44],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 6.712436676025391, 'inference': 26.0159969329834, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 111.,    4., 1078.,  712.]])
# Centroid for Track ID 1: (tensor(594.), tensor(358.))
#
# 0: 384x640 1 hand, 48.1ms
# Speed: 2.9ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[114,  76,  44],
#         [130,  92,  60],
#         [185, 135,  95],
#         ...,
#         [ 95,  93,  89],
#         [ 95,  93,  89],
#         [ 96,  94,  90]],
#
#        [[114,  76,  44],
#         [131,  93,  61],
#         [188, 138,  98],
#         ...,
#         [ 95,  93,  89],
#         [ 95,  93,  89],
#         [ 96,  94,  90]],
#
#        [[110,  72,  40],
#         [125,  87,  55],
#         [185, 135,  95],
#         ...,
#         [ 95,  93,  89],
#         [ 95,  93,  89],
#         [ 96,  94,  90]],
#
#        ...,
#
#        [[188, 103,  44],
#         [188, 103,  44],
#         [188, 103,  44],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[188, 103,  44],
#         [188, 103,  44],
#         [188, 103,  44],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[188, 103,  44],
#         [188, 103,  44],
#         [188, 103,  44],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.918243408203125, 'inference': 48.11525344848633, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 118.0559,    4.2788, 1083.1881,  716.6212]])
# Centroid for Track ID 1: (tensor(600.), tensor(360.))
#
# 0: 384x640 1 hand, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[105,  70,  39],
#         [ 97,  62,  31],
#         [126,  80,  47],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        [[115,  80,  49],
#         [105,  70,  39],
#         [138,  92,  59],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        [[124,  90,  62],
#         [114,  80,  52],
#         [150, 105,  69],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        ...,
#
#        [[185, 102,  45],
#         [185, 102,  45],
#         [185, 102,  45],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[185, 102,  45],
#         [185, 102,  45],
#         [185, 102,  45],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[185, 102,  45],
#         [185, 102,  45],
#         [185, 102,  45],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.9970664978027344, 'inference': 4.8160552978515625, 'postprocess': 4.23741340637207}]
# Track IDs: [1]
# Boxes: tensor([[ 127.9054,    3.6692, 1086.4158,  715.2212]])
# Centroid for Track ID 1: (tensor(607.), tensor(359.))
#
# 0: 384x640 1 hand, 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[134,  90,  57],
#         [103,  59,  26],
#         [108,  65,  34],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        [[136,  92,  59],
#         [103,  59,  26],
#         [107,  64,  33],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        [[137,  95,  62],
#         [101,  59,  26],
#         [103,  63,  31],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        ...,
#
#        [[187, 101,  45],
#         [187, 101,  45],
#         [187, 101,  45],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[187, 101,  45],
#         [187, 101,  45],
#         [187, 101,  45],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[187, 101,  45],
#         [187, 101,  45],
#         [187, 101,  45],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.2230873107910156, 'inference': 7.337093353271484, 'postprocess': 1.4586448669433594}]
# Track IDs: [1]
# Boxes: tensor([[ 135.3851,    4.8989, 1084.2443,  714.5610]])
# Centroid for Track ID 1: (tensor(609.), tensor(359.))
#
# 0: 384x640 1 hand, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[184, 134,  92],
#         [139,  89,  47],
#         [ 92,  58,  30],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        [[184, 134,  92],
#         [139,  89,  47],
#         [ 92,  58,  30],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        [[185, 135,  93],
#         [141,  91,  49],
#         [ 92,  58,  30],
#         ...,
#         [ 96,  94,  90],
#         [ 96,  94,  90],
#         [ 96,  94,  90]],
#
#        ...,
#
#        [[187, 102,  43],
#         [187, 102,  43],
#         [187, 102,  43],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[187, 102,  43],
#         [187, 102,  43],
#         [187, 102,  43],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[187, 102,  43],
#         [187, 102,  43],
#         [187, 102,  43],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.165151596069336, 'inference': 8.960485458374023, 'postprocess': 1.3773441314697266}]
# Track IDs: [1]
# Boxes: tensor([[ 140.3996,    4.4750, 1091.6335,  717.9655]])
# Centroid for Track ID 1: (tensor(616.), tensor(361.))
#
# 0: 384x640 1 hand, 5.7ms
# Speed: 1.1ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 95,  68,  45],
#         [ 88,  61,  38],
#         [ 82,  60,  30],
#         ...,
#         [ 98,  95,  89],
#         [ 98,  95,  89],
#         [ 98,  95,  89]],
#
#        [[118,  91,  68],
#         [104,  77,  54],
#         [ 88,  66,  36],
#         ...,
#         [ 98,  95,  89],
#         [ 98,  95,  89],
#         [ 98,  95,  89]],
#
#        [[163, 128,  89],
#         [140, 105,  66],
#         [100,  72,  38],
#         ...,
#         [ 98,  95,  89],
#         [ 98,  95,  89],
#         [ 98,  95,  89]],
#
#        ...,
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.132965087890625, 'inference': 5.703210830688477, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 146.8224,    4.3037, 1112.6982,  730.4443]])
# Centroid for Track ID 1: (tensor(629.), tensor(367.))
#
# 0: 384x640 1 hand, 3.7ms
# Speed: 2.0ms preprocess, 3.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 78,  45,  28],
#         [ 82,  49,  32],
#         [ 80,  48,  33],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[ 84,  51,  34],
#         [ 87,  54,  37],
#         [ 83,  51,  36],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[112,  78,  50],
#         [103,  69,  41],
#         [ 89,  58,  34],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.007007598876953, 'inference': 3.748655319213867, 'postprocess': 5.501031875610352}]
# Track IDs: [1]
# Boxes: tensor([[ 160.6250,    3.3944, 1132.4412,  746.4474]])
# Centroid for Track ID 1: (tensor(646.), tensor(374.))
#
# 0: 384x640 1 hand, 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 77,  61,  32],
#         [ 70,  54,  25],
#         [ 71,  55,  33],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[ 88,  72,  43],
#         [ 65,  49,  20],
#         [ 71,  55,  33],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[119,  92,  56],
#         [ 82,  55,  19],
#         [ 74,  53,  25],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.0, 'inference': 5.603790283203125, 'postprocess': 5.381345748901367}]
# Track IDs: [1]
# Boxes: tensor([[ 181.7990,    3.7277, 1148.1416,  749.9692]])
# Centroid for Track ID 1: (tensor(664.), tensor(376.))
#
# 0: 384x640 1 hand, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 76,  54,  29],
#         [ 73,  51,  26],
#         [ 74,  50,  30],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[ 94,  72,  47],
#         [ 78,  56,  31],
#         [ 76,  52,  32],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[125,  97,  63],
#         [ 99,  71,  37],
#         [ 77,  51,  26],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 35,  67,  94],
#         [ 35,  67,  94]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 37,  66,  94],
#         [ 37,  66,  94],
#         [ 37,  66,  94]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.9998550415039062, 'inference': 7.251262664794922, 'postprocess': 5.446910858154297}]
# Track IDs: [1]
# Boxes: tensor([[ 202.1391,    3.1060, 1158.9438,  746.2682]])
# Centroid for Track ID 1: (tensor(680.), tensor(374.))
#
# 0: 384x640 1 hand, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 68,  49,  28],
#         [ 67,  48,  27],
#         [ 68,  49,  28],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[ 68,  49,  28],
#         [ 67,  48,  27],
#         [ 69,  50,  29],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        [[ 84,  66,  42],
#         [ 74,  56,  32],
#         [ 72,  53,  32],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.0004043579101562, 'inference': 4.997968673706055, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 215.8790,    3.5778, 1152.9016,  744.6032]])
# Centroid for Track ID 1: (tensor(684.), tensor(374.))
#
# 0: 384x640 1 hand, 8.1ms
# Speed: 0.1ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 72,  48,  28],
#         [ 73,  49,  29],
#         [ 71,  47,  29],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 71,  47,  27],
#         [ 72,  48,  28],
#         [ 71,  47,  29],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 71,  48,  25],
#         [ 71,  48,  25],
#         [ 68,  47,  26],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.1323223114013672, 'inference': 8.134126663208008, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 233.2779,    4.4255, 1158.9905,  754.5566]])
# Centroid for Track ID 1: (tensor(696.), tensor(379.))
#
# 0: 384x640 1 hand, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 75,  47,  27],
#         [ 75,  47,  27],
#         [ 74,  46,  28],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 74,  46,  26],
#         [ 74,  46,  26],
#         [ 74,  46,  28],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 72,  46,  26],
#         [ 74,  48,  28],
#         [ 73,  47,  27],
#         ...,
#         [ 98,  94,  90],
#         [ 98,  94,  90],
#         [ 98,  94,  90]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.849102020263672, 'inference': 5.630016326904297, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 250.6046,    3.3845, 1158.8406,  754.7854]])
# Centroid for Track ID 1: (tensor(704.), tensor(379.))
#
# 0: 384x640 1 hand, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  47,  29],
#         [ 73,  47,  29],
#         [ 76,  48,  30],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 73,  47,  29],
#         [ 73,  47,  29],
#         [ 75,  47,  29],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 75,  47,  27],
#         [ 74,  46,  26],
#         [ 74,  47,  24],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.0303726196289062, 'inference': 9.160280227661133, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 274.0463,    2.9988, 1167.9232,  758.0513]])
# Centroid for Track ID 1: (tensor(720.), tensor(380.))
#
# 0: 384x640 1 hand, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 71,  48,  25],
#         [ 71,  48,  25],
#         [ 71,  48,  25],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 73,  50,  27],
#         [ 72,  49,  26],
#         [ 72,  49,  26],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        [[ 73,  50,  27],
#         [ 72,  49,  26],
#         [ 72,  49,  26],
#         ...,
#         [ 99,  95,  91],
#         [ 99,  95,  91],
#         [ 99,  95,  91]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.9931793212890625, 'inference': 8.283853530883789, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 290.1491,    2.8441, 1169.6229,  764.4430]])
# Centroid for Track ID 1: (tensor(729.), tensor(383.))
#
# 0: 384x640 1 hand, 2.8ms
# Speed: 1.0ms preprocess, 2.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  48,  25],
#         [ 73,  48,  25],
#         [ 73,  48,  25],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        [[ 73,  48,  25],
#         [ 73,  48,  25],
#         [ 73,  48,  25],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        [[ 73,  48,  25],
#         [ 73,  48,  25],
#         [ 73,  48,  25],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.9977817535400391, 'inference': 2.7618408203125, 'postprocess': 5.37109375}]
# Track IDs: [1]
# Boxes: tensor([[ 306.2023,    4.7731, 1180.6747,  775.2896]])
# Centroid for Track ID 1: (tensor(743.), tensor(390.))
#
# 0: 384x640 1 hand, 5.7ms
# Speed: 3.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 72,  46,  26],
#         [ 71,  45,  25],
#         [ 71,  46,  23],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        [[ 71,  45,  25],
#         [ 71,  45,  25],
#         [ 71,  46,  23],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        [[ 74,  46,  26],
#         [ 74,  46,  26],
#         [ 72,  47,  24],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.9718875885009766, 'inference': 5.736589431762695, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 323.0265,    6.8418, 1200.6165,  784.4507]])
# Centroid for Track ID 1: (tensor(761.), tensor(395.))
#
# 0: 384x640 1 hand, 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  47,  27],
#         [ 73,  47,  27],
#         [ 73,  47,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 73,  47,  27],
#         [ 73,  47,  27],
#         [ 73,  47,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 73,  47,  27],
#         [ 73,  47,  27],
#         [ 73,  47,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.0628700256347656, 'inference': 4.580020904541016, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 335.3213,   11.5482, 1210.3417,  800.2015]])
# Centroid for Track ID 1: (tensor(772.), tensor(405.))
#
# 0: 384x640 1 hand, 2.6ms
# Speed: 2.0ms preprocess, 2.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 71,  45,  27],
#         [ 71,  45,  27],
#         [ 71,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 71,  45,  27],
#         [ 71,  45,  27],
#         [ 71,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 71,  45,  27],
#         [ 71,  45,  27],
#         [ 71,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.9998550415039062, 'inference': 2.5985240936279297, 'postprocess': 5.9070587158203125}]
# Track IDs: [1]
# Boxes: tensor([[ 351.2849,   21.8628, 1206.2207,  813.9071]])
# Centroid for Track ID 1: (tensor(778.), tensor(417.))
#
# 0: 384x640 1 hand, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.0258426666259766, 'inference': 7.018804550170898, 'postprocess': 1.1413097381591797}]
# Track IDs: [1]
# Boxes: tensor([[ 373.3560,   34.9164, 1204.3269,  820.1480]])
# Centroid for Track ID 1: (tensor(788.), tensor(427.))
#
# 0: 384x640 1 hand, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        [[ 74,  46,  28],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [101,  97,  93],
#         [101,  97,  93],
#         [101,  97,  93]],
#
#        ...,
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.0, 'inference': 10.994911193847656, 'postprocess': 0.0}]
# Track IDs: [1]
# Boxes: tensor([[ 391.6694,   56.3304, 1218.8063,  835.4589]])
# Centroid for Track ID 1: (tensor(805.), tensor(445.))
#
# 0: 384x640 1 hand, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        [[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [100,  96,  92],
#         [100,  96,  92],
#         [100,  96,  92]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.9989738464355469, 'inference': 7.935285568237305, 'postprocess': 1.0082721710205078}]
# Track IDs: [1]
# Boxes: tensor([[ 404.5020,   75.5526, 1225.1825,  856.7822]])
# Centroid for Track ID 1: (tensor(814.), tensor(466.))
#
# 0: 384x640 1 hand, 7.8ms
# Speed: 3.0ms preprocess, 7.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 75,  73,  69],
#         [ 76,  74,  70],
#         [ 76,  74,  70]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 78,  76,  72],
#         [ 80,  78,  74],
#         [ 80,  78,  74]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 82,  78,  74],
#         [ 82,  78,  74],
#         [ 84,  80,  76]],
#
#        ...,
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 34,  63,  91],
#         [ 34,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
#         [ 34,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
#         [ 34,  63,  91]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.953767776489258, 'inference': 7.781028747558594, 'postprocess': 4.272937774658203}]
# Track IDs: [1]
# Boxes: tensor([[ 416.5966,   96.9859, 1232.6780,  878.3137]])
# Centroid for Track ID 1: (tensor(824.), tensor(487.))
#
# 0: 384x640 1 hand, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 39,  33,  21],
#         [ 39,  33,  21],
#         [ 39,  33,  21]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 39,  33,  21],
#         [ 39,  33,  21],
#         [ 39,  33,  21]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 39,  33,  21],
#         [ 39,  33,  21],
#         [ 39,  33,  21]],
#
#        ...,
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 34,  63,  91],
#         [ 34,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
#         [ 34,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
#         [ 34,  63,  91]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.0, 'inference': 8.36491584777832, 'postprocess': 1.0018348693847656}]
# Track IDs: [1]
# Boxes: tensor([[ 428.5588,  109.4654, 1243.8960,  897.2572]])
# Centroid for Track ID 1: (tensor(836.), tensor(503.))
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 40,  34,  22],
#         [ 40,  34,  22],
#         [ 40,  34,  22]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 40,  34,  22],
#         [ 40,  34,  22],
#         [ 40,  34,  22]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 40,  34,  22],
#         [ 40,  34,  22],
#         [ 40,  34,  22]],
#
#        ...,
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
#         [ 34,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
#         [ 34,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
#         [ 34,  63,  91]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.0, 'inference': 10.149955749511719, 'postprocess': 0.99945068359375}]
# Track IDs: [1]
# Boxes: tensor([[ 445.7707,  124.3885, 1262.4374,  908.6875]])
# Centroid for Track ID 1: (tensor(854.), tensor(516.))
#
# 0: 384x640 1 hand, 6.8ms
# Speed: 1.3ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 46,  35,  26],
#         [ 46,  35,  26],
#         [ 48,  37,  28]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 46,  35,  26],
#         [ 48,  37,  28],
#         [ 48,  37,  28]],
#
#        [[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 46,  35,  26],
#         [ 48,  37,  28],
#         [ 48,  37,  28]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  66,  93],
#         [ 34,  66,  93],
#         [ 34,  66,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.323699951171875, 'inference': 6.7996978759765625, 'postprocess': 0.9996891021728516}]
# Track IDs: [1]
# Boxes: tensor([[ 459.5320,  146.1345, 1282.4023,  921.7202]])
# Centroid for Track ID 1: (tensor(870.), tensor(533.))
#
# 0: 384x640 1 hand, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 75,  44,  27],
#         [ 75,  44,  27],
#         [ 75,  44,  27],
#         ...,
#         [ 46,  35,  26],
#         [ 46,  35,  26],
#         [ 46,  35,  26]],
#
#        [[ 75,  44,  27],
#         [ 75,  44,  27],
#         [ 75,  44,  27],
#         ...,
#         [ 46,  35,  26],
#         [ 46,  35,  26],
#         [ 46,  35,  26]],
#
#        [[ 75,  44,  27],
#         [ 75,  44,  27],
#         [ 75,  44,  27],
#         ...,
#         [ 46,  35,  26],
#         [ 46,  35,  26],
#         [ 46,  35,  26]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 3.2434463500976562, 'inference': 10.53309440612793, 'postprocess': 1.8317699432373047}]
# Track IDs: [1]
# Boxes: tensor([[ 466.8333,  179.8552, 1292.8193,  931.5654]])
# Centroid for Track ID 1: (tensor(879.), tensor(555.))
#
# 0: 384x640 1 hand, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 36,  28,  18],
#         [ 36,  28,  18],
#         [ 36,  28,  18]],
#
#        [[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 36,  28,  18],
#         [ 36,  28,  18],
#         [ 36,  28,  18]],
#
#        [[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 36,  28,  18],
#         [ 36,  28,  18],
#         [ 36,  28,  18]],
#
#        ...,
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  65,  93],
#         [ 36,  65,  93],
#         [ 36,  65,  93]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.0, 'inference': 10.168313980102539, 'postprocess': 0.9999275207519531}]
# Track IDs: [1]
# Boxes: tensor([[ 470.9669,  201.4201, 1302.3657,  944.7023]])
# Centroid for Track ID 1: (tensor(886.), tensor(573.))
#
# 0: 384x640 1 hand, 7.6ms
# Speed: 9.1ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 30,  26,  16],
#         [ 30,  26,  16],
#         [ 30,  26,  16]],
#
#        [[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 30,  26,  16],
#         [ 30,  26,  16],
#         [ 30,  26,  16]],
#
#        [[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 30,  26,  16],
#         [ 30,  26,  16],
#         [ 30,  26,  16]],
#
#        ...,
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  63,  91],
#         [ 36,  63,  91],
#         [ 36,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  63,  91],
#         [ 36,  63,  91],
#         [ 36,  63,  91]],
#
#        [[184, 101,  44],
#         [184, 101,  44],
#         [184, 101,  44],
#         ...,
#         [ 36,  63,  91],
#         [ 36,  63,  91],
#         [ 36,  63,  91]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 9.081602096557617, 'inference': 7.551431655883789, 'postprocess': 1.0006427764892578}]
# Track IDs: [1]
# Boxes: tensor([[ 484.6556,  236.9059, 1332.7053,  959.1221]])
# Centroid for Track ID 1: (tensor(908.), tensor(598.))
#
# 0: 384x640 1 hand, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 73,  45,  27],
#         [ 73,  45,  27],
#         [ 73,  45,  27],
#         ...,
#         [ 30,  24,  12],
#         [ 30,  24,  12],
#         [ 30,  24,  12]],
#
#        [[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 30,  24,  12],
#         [ 30,  24,  12],
#         [ 30,  24,  12]],
#
#        [[ 74,  46,  28],
#         [ 74,  46,  28],
#         [ 74,  46,  28],
#         ...,
#         [ 30,  24,  12],
#         [ 30,  24,  12],
#         [ 30,  24,  12]],
#
#        ...,
#
#        [[184, 102,  42],
#         [184, 102,  42],
#         [184, 102,  42],
#         ...,
#         [ 34,  63,  91],
#         [ 34,  63,  91],
# ...
#         ...,
#         [ 60, 103, 156],
#         [ 58, 103, 158],
#         [ 59, 104, 159]],
#
#        [[183, 104,  61],
#         [183, 104,  61],
#         [183, 104,  61],
#         ...,
#         [ 60, 103, 156],
#         [ 58, 103, 158],
#         [ 58, 103, 158]],
#
#        [[183, 104,  61],
#         [183, 104,  61],
#         [183, 104,  61],
#         ...,
#         [ 60, 103, 156],
#         [ 58, 103, 158],
#         [ 58, 103, 158]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.0056495666503906, 'inference': 10.362863540649414, 'postprocess': 0.0}]
# Track IDs: [2]
# Boxes: tensor([[ 634.2438,    7.0606, 1369.2637,  670.3787]])
# Centroid for Track ID 2: (tensor(1001.), tensor(338.))
#
# 0: 384x640 1 hand, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 69,  43,  30],
#         [ 69,  43,  30],
#         [ 69,  43,  30],
#         ...,
#         [107, 107, 114],
#         [107, 107, 114],
#         [107, 107, 114]],
#
#        [[ 69,  43,  30],
#         [ 69,  43,  30],
#         [ 69,  43,  30],
#         ...,
#         [107, 107, 114],
#         [107, 107, 114],
#         [107, 107, 114]],
#
#        [[ 69,  43,  30],
#         [ 69,  43,  30],
#         [ 69,  43,  30],
#         ...,
#         [107, 107, 114],
#         [107, 107, 114],
#         [107, 107, 114]],
#
#        ...,
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 61, 104, 157],
#         [ 61, 104, 159],
#         [ 62, 105, 160]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 61, 104, 157],
#         [ 61, 104, 159],
#         [ 61, 104, 159]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 60, 103, 156],
#         [ 60, 103, 158],
#         [ 61, 104, 159]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 4.0149688720703125, 'inference': 10.024785995483398, 'postprocess': 2.0003318786621094}]
# Track IDs: [2]
# Boxes: tensor([[ 638.1659,    5.3042, 1371.8837,  666.2729]])
# Centroid for Track ID 2: (tensor(1005.), tensor(335.))
#
# 0: 384x640 1 hand, 10.7ms
# Speed: 3.4ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 70,  44,  31],
#         [ 70,  44,  31],
#         [ 70,  44,  31],
#         ...,
#         [105, 107, 114],
#         [105, 107, 114],
#         [105, 107, 114]],
#
#        [[ 70,  44,  31],
#         [ 70,  44,  31],
#         [ 70,  44,  31],
#         ...,
#         [105, 107, 114],
#         [105, 107, 114],
#         [105, 107, 114]],
#
#        [[ 70,  44,  31],
#         [ 70,  44,  31],
#         [ 70,  44,  31],
#         ...,
#         [105, 107, 114],
#         [105, 107, 114],
#         [105, 107, 114]],
#
#        ...,
#
#        [[183, 104,  61],
#         [183, 104,  61],
#         [183, 104,  61],
#         ...,
#         [ 61, 104, 157],
#         [ 61, 104, 159],
#         [ 62, 105, 160]],
#
#        [[183, 104,  61],
#         [183, 104,  61],
#         [183, 104,  61],
#         ...,
#         [ 61, 104, 157],
#         [ 61, 104, 159],
#         [ 61, 104, 159]],
#
#        [[183, 104,  61],
#         [183, 104,  61],
#         [183, 104,  61],
#         ...,
#         [ 60, 103, 156],
#         [ 60, 103, 158],
#         [ 61, 104, 159]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 3.3571720123291016, 'inference': 10.68258285522461, 'postprocess': 1.3523101806640625}]
# Track IDs: [2]
# Boxes: tensor([[ 639.1458,    8.0396, 1369.9257,  661.0510]])
# Centroid for Track ID 2: (tensor(1004.), tensor(334.))
#
# 0: 384x640 1 hand, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 70,  44,  31],
#         [ 70,  44,  31],
#         [ 70,  44,  31],
#         ...,
#         [107, 107, 114],
#         [107, 107, 114],
#         [107, 107, 114]],
#
#        [[ 70,  44,  31],
#         [ 70,  44,  31],
#         [ 70,  44,  31],
#         ...,
#         [107, 107, 114],
#         [107, 107, 114],
#         [107, 107, 114]],
#
#        [[ 70,  44,  31],
#         [ 70,  44,  31],
#         [ 70,  44,  31],
#         ...,
#         [107, 107, 114],
#         [107, 107, 114],
#         [107, 107, 114]],
#
#        ...,
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 60, 103, 156],
#         [ 62, 103, 156],
#         [ 62, 103, 156]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 60, 103, 156],
#         [ 62, 103, 156],
#         [ 62, 103, 156]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 59, 102, 155],
#         [ 61, 102, 155],
#         [ 61, 102, 155]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.0, 'inference': 10.130882263183594, 'postprocess': 0.0}]
# Track IDs: [2]
# Boxes: tensor([[ 644.3369,    9.6770, 1370.9882,  656.0435]])
# Centroid for Track ID 2: (tensor(1007.), tensor(332.))
#
# 0: 384x640 1 hand, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [106, 108, 115],
#         [106, 108, 115],
#         [106, 108, 115]],
#
#        [[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [106, 108, 115],
#         [106, 108, 115],
#         [106, 108, 115]],
#
#        [[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [106, 108, 115],
#         [106, 108, 115],
#         [106, 108, 115]],
#
#        ...,
#
#        [[180, 103,  61],
#         [180, 103,  61],
#         [180, 103,  61],
#         ...,
#         [ 62, 103, 156],
#         [ 64, 102, 156],
#         [ 64, 102, 156]],
#
#        [[180, 103,  61],
#         [180, 103,  61],
#         [180, 103,  61],
#         ...,
#         [ 62, 103, 156],
#         [ 64, 102, 156],
#         [ 64, 102, 156]],
#
#        [[180, 103,  61],
#         [180, 103,  61],
#         [180, 103,  61],
#         ...,
#         [ 62, 103, 156],
#         [ 64, 102, 156],
#         [ 64, 102, 156]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.0, 'inference': 16.486167907714844, 'postprocess': 0.9970664978027344}]
# Track IDs: [2]
# Boxes: tensor([[ 648.1372,   11.5186, 1373.3943,  653.0773]])
# Centroid for Track ID 2: (tensor(1010.), tensor(332.))
#
# 0: 384x640 1 hand, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        [[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        [[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        ...,
#
#        [[181, 104,  62],
#         [181, 104,  62],
#         [181, 104,  62],
#         ...,
#         [ 60, 103, 156],
#         [ 62, 103, 156],
#         [ 62, 103, 156]],
#
#        [[181, 104,  62],
#         [181, 104,  62],
#         [181, 104,  62],
#         ...,
#         [ 60, 103, 156],
#         [ 62, 103, 156],
#         [ 62, 103, 156]],
#
#        [[181, 104,  62],
#         [181, 104,  62],
#         [181, 104,  62],
#         ...,
#         [ 60, 103, 156],
#         [ 62, 103, 156],
#         [ 62, 103, 156]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.294851303100586, 'inference': 11.521577835083008, 'postprocess': 1.0030269622802734}]
# Track IDs: [2]
# Boxes: tensor([[ 649.8154,   15.7912, 1372.9196,  651.9811]])
# Centroid for Track ID 2: (tensor(1011.), tensor(333.))
#
# 0: 384x640 1 hand, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        [[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        [[ 71,  45,  32],
#         [ 71,  45,  32],
#         [ 71,  45,  32],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        ...,
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 61, 104, 157],
#         [ 61, 104, 157],
#         [ 61, 104, 157]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 61, 104, 157],
#         [ 61, 104, 157],
#         [ 61, 104, 157]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 61, 104, 157],
#         [ 61, 104, 157],
#         [ 61, 104, 157]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.028226852416992, 'inference': 9.220600128173828, 'postprocess': 0.24127960205078125}]
# Track IDs: [2]
# Boxes: tensor([[ 652.7629,   13.0878, 1381.1890,  654.1804]])
# Centroid for Track ID 2: (tensor(1016.), tensor(333.))
#
# 0: 384x640 1 hand, 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 72,  46,  33],
#         [ 72,  46,  33],
#         [ 72,  46,  33],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        [[ 72,  46,  33],
#         [ 72,  46,  33],
#         [ 72,  46,  33],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        [[ 72,  46,  33],
#         [ 72,  46,  33],
#         [ 72,  46,  33],
#         ...,
#         [109, 109, 116],
#         [109, 109, 116],
#         [109, 109, 116]],
#
#        ...,
#
#        [[180, 104,  60],
#         [180, 104,  60],
#         [180, 104,  60],
#         ...,
#         [ 55, 105, 157],
#         [ 53, 106, 159],
#         [ 53, 106, 159]],
#
#        [[180, 104,  60],
#         [180, 104,  60],
#         [180, 104,  60],
#         ...,
#         [ 55, 105, 157],
#         [ 55, 105, 159],
#         [ 55, 105, 159]],
#
#        [[180, 104,  60],
#         [180, 104,  60],
#         [180, 104,  60],
#         ...,
#         [ 55, 105, 157],
#         [ 55, 105, 159],
#         [ 55, 105, 159]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 2.0902156829833984, 'inference': 13.506174087524414, 'postprocess': 2.1147727966308594}]
# Track IDs: [2]
# Boxes: tensor([[ 654.0739,   10.1611, 1388.1027,  664.5497]])
# Centroid for Track ID 2: (tensor(1021.), tensor(337.))
#
# 0: 384x640 1 hand, 12.2ms
# Speed: 1.5ms preprocess, 12.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 72,  46,  33],
#         [ 72,  46,  33],
#         [ 72,  46,  33],
#         ...,
#         [108, 108, 115],
#         [108, 108, 115],
#         [108, 108, 115]],
#
#        [[ 72,  46,  33],
#         [ 72,  46,  33],
#         [ 72,  46,  33],
#         ...,
#         [108, 108, 115],
#         [108, 108, 115],
#         [108, 108, 115]],
#
#        [[ 72,  46,  33],
#         [ 72,  46,  33],
#         [ 72,  46,  33],
#         ...,
#         [108, 108, 115],
#         [108, 108, 115],
#         [108, 108, 115]],
#
#        ...,
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 59, 104, 157],
#         [ 57, 105, 159],
#         [ 57, 105, 159]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 59, 104, 157],
#         [ 59, 104, 159],
#         [ 59, 104, 159]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 59, 104, 157],
#         [ 59, 104, 159],
#         [ 59, 104, 159]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 1.4851093292236328, 'inference': 12.210607528686523, 'postprocess': 2.523183822631836}]
# Track IDs: [2]
# Boxes: tensor([[ 652.3397,   10.5916, 1393.2905,  675.3790]])
# Centroid for Track ID 2: (tensor(1022.), tensor(342.))
#
# 0: 384x640 1 hand, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'hand'}
# obb: None
# orig_img: array([[[ 69,  46,  32],
#         [ 69,  46,  32],
#         [ 69,  46,  32],
#         ...,
#         [106, 109, 114],
#         [106, 109, 114],
#         [106, 109, 114]],
#
#        [[ 69,  46,  32],
#         [ 69,  46,  32],
#         [ 69,  46,  32],
#         ...,
#         [106, 109, 114],
#         [106, 109, 114],
#         [106, 109, 114]],
#
#        [[ 69,  46,  32],
#         [ 69,  46,  32],
#         [ 69,  46,  32],
#         ...,
#         [106, 109, 114],
#         [106, 109, 114],
#         [106, 109, 114]],
#
#        ...,
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 57, 105, 157],
#         [ 57, 105, 157],
#         [ 57, 105, 157]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 57, 105, 157],
#         [ 57, 105, 157],
#         [ 57, 105, 157]],
#
#        [[181, 105,  61],
#         [181, 105,  61],
#         [181, 105,  61],
#         ...,
#         [ 57, 105, 157],
#         [ 57, 105, 157],
#         [ 57, 105, 157]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\pose\\track'
# speed: {'preprocess': 0.9973049163818359, 'inference': 11.269092559814453, 'postprocess': 1.0025501251220703}]
# Track IDs: [2]
# Boxes: tensor([[ 652.0266,   10.9213, 1393.6991,  684.2563]])
# Centroid for Track ID 2: (tensor(1022.), tensor(347.))
# Video frame is empty or video processing has been successfully completed.
